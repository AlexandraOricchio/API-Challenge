# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os 

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = os.path.join("output_data","cities.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 613

# %% [markdown]
# ## Perform API Calls
#     Perform a weather check on each city using a series of successive API calls.
#     Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
## Create dataframe of cities in list with empty columns for data
df=pd.DataFrame(cities)
df=df.rename(columns={0:'City'})
df['Cloudiness']=''
df['Country']=''
df['Date']=''
df['Humidity']=''
df['Lat']=''
df['Lng']=''
df['Max Temp']=''
df['Wind Speed']=''
print(df.shape)
df.head()
# Out:
# (613, 9)
#          City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0  oranjemund
# 1     mataura
# 2   anklesvar
# 3  vila velha
# 4   busselton

# %%
## create base url and parameters
base_url="http://api.openweathermap.org/data/2.5/weather?"
params={"units":"imperial",
       "APPID":api_key}

# %%
count=1

for index, row in df.iterrows():
    
    # get city from dataframe
    city_name=row['City']
    
    # add new key to params for query search by city name
    params['q']=city_name
    
    # assemble url and make api request
    response=requests.get(base_url,params=params).json()
    
    try:
        print(f'Processing Record {count}: {city_name}')
    
        df.loc[index, 'Cloudiness']=response['clouds']['all']
        df.loc[index, 'Country']=response['sys']['country']
        df.loc[index, 'Date']=response['dt']
        df.loc[index,'Humidity']=response['main']['humidity']
        df.loc[index,'Lat']=response['coord']['lat']
        df.loc[index,'Lng']=response['coord']['lon']
        df.loc[index,'Max Temp']=response['main']['temp_max']
        df.loc[index,'Wind Speed']=response['wind']['speed']
    except(KeyError):
        print("Missing field/result...skipping")
    
    count=count+1
# Out:
# Processing Record 1: oranjemund
# Processing Record 2: mataura
# Processing Record 3: anklesvar
# Missing field/result...skipping
# Processing Record 4: vila velha
# Processing Record 5: busselton
# Processing Record 6: barrow
# Processing Record 7: pevek
# Processing Record 8: clyde river
# Processing Record 9: noumea
# Processing Record 10: mabaruma
# Processing Record 11: warqla
# Missing field/result...skipping
# Processing Record 12: ribeira grande
# Processing Record 13: rikitea
# Processing Record 14: evensk
# Processing Record 15: ushuaia
# Processing Record 16: nizwa
# Processing Record 17: hermanus
# Processing Record 18: esperance
# Processing Record 19: saint-francois
# Processing Record 20: kapaa
# Processing Record 21: chunoyar
# Processing Record 22: tual
# Processing Record 23: vao
# Processing Record 24: vaitupu
# Missing field/result...skipping
# Processing Record 25: hobart
# Processing Record 26: tasiilaq
# Processing Record 27: saleaula
# Missing field/result...skipping
# Processing Record 28: albany
# Processing Record 29: chitral
# Processing Record 30: georgetown
# Processing Record 31: riachao das neves
# Processing Record 32: atuona
# Processing Record 33: punta arenas
# Processing Record 34: butaritari
# Processing Record 35: kaithal
# Processing Record 36: nikolskoye
# Processing Record 37: dawson creek
# Processing Record 38: kaitangata
# Processing Record 39: wahran
# Missing field/result...skipping
# Processing Record 40: jakar
# Processing Record 41: pandan
# Processing Record 42: saint-joseph
# Processing Record 43: provideniya
# Processing Record 44: pichayevo
# Processing Record 45: vaini
# Processing Record 46: bengkulu
# Missing field/result...skipping
# Processing Record 47: mapimi
# Processing Record 48: abu jubayhah
# Missing field/result...skipping
# Processing Record 49: samarai
# Processing Record 50: hithadhoo
# Processing Record 51: bambous virieux
# Processing Record 52: matadi
# Processing Record 53: castro
# Processing Record 54: jamestown
# Processing Record 55: mys shmidta
# Missing field/result...skipping
# Processing Record 56: cape town
# Processing Record 57: praia da vitoria
# Processing Record 58: lebu
# Processing Record 59: taolanaro
# Missing field/result...skipping
# Processing Record 60: kahului
# Processing Record 61: mar del plata
# Processing Record 62: toliary
# Missing field/result...skipping
# Processing Record 63: aleysk
# Processing Record 64: jacqueville
# Processing Record 65: bluff
# Processing Record 66: naron
# Processing Record 67: zhangjiakou
# Processing Record 68: okha
# Processing Record 69: saskylakh
# Processing Record 70: dudinka
# Processing Record 71: tevaitoa
# Processing Record 72: calama
# Processing Record 73: port alfred
# Processing Record 74: illoqqortoormiut
# Missing field/result...skipping
# Processing Record 75: abu samrah
# Processing Record 76: samalaeulu
# Missing field/result...skipping
# Processing Record 77: krasnoselkup
# Missing field/result...skipping
# Processing Record 78: new norfolk
# Processing Record 79: port lincoln
# Processing Record 80: tiksi
# Processing Record 81: coxim
# Processing Record 82: witu
# Processing Record 83: norman wells
# Processing Record 84: bredasdorp
# Processing Record 85: grand gaube
# Processing Record 86: severo-kurilsk
# Processing Record 87: mount gambier
# Processing Record 88: faanui
# Processing Record 89: arcachon
# Processing Record 90: fereydun kenar
# Processing Record 91: carnarvon
# Processing Record 92: yellowknife
# Processing Record 93: nemuro
# Processing Record 94: tateyama
# Processing Record 95: poronaysk
# Processing Record 96: tuktoyaktuk
# Processing Record 97: saint george
# Processing Record 98: tautira
# Processing Record 99: torbay
# Processing Record 100: cabo san lucas
# Processing Record 101: soritor
# Processing Record 102: barra patuca
# Processing Record 103: teya
# Processing Record 104: geraldton
# Processing Record 105: aracatuba
# Processing Record 106: hilo
# Processing Record 107: bermejillo
# Processing Record 108: fairlie
# Processing Record 109: namibe
# Processing Record 110: thompson
# Processing Record 111: sayyan
# Processing Record 112: san cristobal
# Processing Record 113: bongandanga
# Processing Record 114: rozhnyativ
# Processing Record 115: ponta do sol
# Processing Record 116: avarua
# Processing Record 117: talnakh
# Processing Record 118: trinidad
# Processing Record 119: bethel
# Processing Record 120: srednekolymsk
# Processing Record 121: chokurdakh
# Processing Record 122: tumannyy
# Missing field/result...skipping
# Processing Record 123: amnat charoen
# Processing Record 124: faya
# Processing Record 125: lompoc
# Processing Record 126: canyon
# Processing Record 127: claudio
# Processing Record 128: victoria
# Processing Record 129: meyungs
# Missing field/result...skipping
# Processing Record 130: aldan
# Processing Record 131: arraial do cabo
# Processing Record 132: necochea
# Processing Record 133: araouane
# Processing Record 134: saint-philippe
# Processing Record 135: lere
# Processing Record 136: gat
# Processing Record 137: sur
# Processing Record 138: callaway
# Processing Record 139: carutapera
# Processing Record 140: acajutla
# Processing Record 141: weida
# Processing Record 142: nador
# Processing Record 143: tigil
# Processing Record 144: balkanabat
# Processing Record 145: guerrero negro
# Processing Record 146: souillac
# Processing Record 147: kapit
# Processing Record 148: san patricio
# Processing Record 149: papasquiaro
# Missing field/result...skipping
# Processing Record 150: cacequi
# Processing Record 151: daytona beach
# Processing Record 152: mahebourg
# Processing Record 153: lilongwe
# Processing Record 154: boa vista
# Processing Record 155: nola
# Processing Record 156: karaul
# Missing field/result...skipping
# Processing Record 157: rio grande
# Processing Record 158: codrington
# Processing Record 159: port macquarie
# Processing Record 160: vila franca do campo
# Processing Record 161: hualmay
# Processing Record 162: havelock
# Processing Record 163: marystown
# Processing Record 164: uarini
# Processing Record 165: itabaiana
# Processing Record 166: kropotkin
# Processing Record 167: hobyo
# Processing Record 168: ye
# Missing field/result...skipping
# Processing Record 169: opunake
# Processing Record 170: fortuna
# Processing Record 171: matsanga
# Missing field/result...skipping
# Processing Record 172: camacha
# Processing Record 173: cidreira
# Processing Record 174: prince rupert
# Processing Record 175: barbar
# Missing field/result...skipping
# Processing Record 176: ust-omchug
# Processing Record 177: caravelas
# Processing Record 178: olafsvik
# Missing field/result...skipping
# Processing Record 179: east london
# Processing Record 180: erenhot
# Processing Record 181: kipushi
# Processing Record 182: inverell
# Processing Record 183: arica
# Processing Record 184: antofagasta
# Processing Record 185: peace river
# Processing Record 186: cherskiy
# Processing Record 187: omboue
# Processing Record 188: albanel
# Processing Record 189: samoylovka
# Processing Record 190: madre de deus
# Processing Record 191: lata
# Processing Record 192: margate
# Processing Record 193: saint-pierre
# Processing Record 194: the pas
# Processing Record 195: twin falls
# Processing Record 196: chushan
# Processing Record 197: sidi bin nur
# Processing Record 198: jumla
# Processing Record 199: upernavik
# Processing Record 200: kavieng
# Processing Record 201: ruatoria
# Missing field/result...skipping
# Processing Record 202: luanda
# Processing Record 203: shenjiamen
# Processing Record 204: aswan
# Processing Record 205: the valley
# Processing Record 206: kodiak
# Processing Record 207: pisco
# Processing Record 208: cacu
# Processing Record 209: constitucion
# Processing Record 210: port elizabeth
# Processing Record 211: ventspils
# Processing Record 212: algiers
# Processing Record 213: groningen
# Processing Record 214: mont-de-marsan
# Processing Record 215: bria
# Processing Record 216: les cayes
# Processing Record 217: krylovskaya
# Processing Record 218: mmathubudukwane
# Processing Record 219: lagoa
# Processing Record 220: sitka
# Processing Record 221: acarau
# Missing field/result...skipping
# Processing Record 222: nizhneyansk
# Missing field/result...skipping
# Processing Record 223: yarensk
# Processing Record 224: flinders
# Processing Record 225: touros
# Processing Record 226: zhigansk
# Processing Record 227: blind river
# Processing Record 228: yerbogachen
# Processing Record 229: mundo nuevo
# Processing Record 230: komsomolskiy
# Processing Record 231: atar
# Processing Record 232: hamina
# Processing Record 233: kruisfontein
# Processing Record 234: sentyabrskiy
# Missing field/result...skipping
# Processing Record 235: korla
# Missing field/result...skipping
# Processing Record 236: chagda
# Missing field/result...skipping
# Processing Record 237: oistins
# Processing Record 238: airai
# Processing Record 239: khatanga
# Processing Record 240: jambi
# Processing Record 241: elbistan
# Processing Record 242: aksay
# Processing Record 243: buraydah
# Processing Record 244: tuatapere
# Processing Record 245: williams lake
# Processing Record 246: ancud
# Processing Record 247: honiara
# Processing Record 248: mayo
# Processing Record 249: kirakira
# Processing Record 250: kostomuksha
# Processing Record 251: walvis bay
# Processing Record 252: lyuban
# Processing Record 253: yangambi
# Processing Record 254: manzanillo
# Processing Record 255: nadym
# Processing Record 256: bathsheba
# Processing Record 257: herzele
# Processing Record 258: makakilo city
# Processing Record 259: lamar
# Processing Record 260: posse
# Processing Record 261: hermosillo
# Processing Record 262: kamenskoye
# Missing field/result...skipping
# Processing Record 263: kuche
# Missing field/result...skipping
# Processing Record 264: grindavik
# Processing Record 265: kudahuvadhoo
# Processing Record 266: daru
# Processing Record 267: lima
# Processing Record 268: klaksvik
# Processing Record 269: tazovskiy
# Processing Record 270: naples
# Processing Record 271: narathiwat
# Processing Record 272: agadir
# Processing Record 273: tamandare
# Processing Record 274: itabuna
# Processing Record 275: kutum
# Processing Record 276: annau
# Processing Record 277: cedar city
# Processing Record 278: cabedelo
# Processing Record 279: palaia fokaia
# Processing Record 280: ahipara
# Processing Record 281: fare
# Processing Record 282: willmar
# Processing Record 283: roseburg
# Processing Record 284: sao joao da barra
# Processing Record 285: bekobod
# Processing Record 286: longyearbyen
# Processing Record 287: fallon
# Processing Record 288: kaili
# Processing Record 289: salto
# Processing Record 290: sao filipe
# Processing Record 291: rungata
# Missing field/result...skipping
# Processing Record 292: clinton
# Processing Record 293: vysokaya gora
# Missing field/result...skipping
# Processing Record 294: moron
# Processing Record 295: cockburn town
# Processing Record 296: waingapu
# Processing Record 297: aripuana
# Processing Record 298: sainte-maxime
# Processing Record 299: phan thiet
# Processing Record 300: attawapiskat
# Missing field/result...skipping
# Processing Record 301: tibati
# Processing Record 302: maniitsoq
# Processing Record 303: placido de castro
# Processing Record 304: barentsburg
# Missing field/result...skipping
# Processing Record 305: ahuimanu
# Processing Record 306: togul
# Processing Record 307: umzimvubu
# Missing field/result...skipping
# Processing Record 308: dunedin
# Processing Record 309: grand river south east
# Missing field/result...skipping
# Processing Record 310: qaanaaq
# Processing Record 311: pacific grove
# Processing Record 312: orgun
# Missing field/result...skipping
# Processing Record 313: cayenne
# Processing Record 314: oxford
# Processing Record 315: maceio
# Processing Record 316: chuy
# Processing Record 317: soyo
# Processing Record 318: yar-sale
# Processing Record 319: lapeer
# Processing Record 320: suicheng
# Processing Record 321: qaqortoq
# Processing Record 322: karamay
# Missing field/result...skipping
# Processing Record 323: meulaboh
# Processing Record 324: beyneu
# Processing Record 325: leh
# Processing Record 326: olinda
# Processing Record 327: patitirion
# Processing Record 328: lielvarde
# Processing Record 329: maiduguri
# Processing Record 330: boma
# Processing Record 331: ler
# Processing Record 332: mayumba
# Processing Record 333: calatayud
# Processing Record 334: gao
# Processing Record 335: kungurtug
# Processing Record 336: jiroft
# Missing field/result...skipping
# Processing Record 337: hofn
# Processing Record 338: berea
# Processing Record 339: benguela
# Processing Record 340: puerto ayora
# Processing Record 341: moerai
# Processing Record 342: mutoko
# Processing Record 343: kabanjahe
# Processing Record 344: chateaubelair
# Processing Record 345: stonehaven
# Processing Record 346: darnah
# Processing Record 347: tilichiki
# Processing Record 348: labuhan
# Processing Record 349: katobu
# Processing Record 350: flagstaff
# Processing Record 351: tadine
# Processing Record 352: dumas
# Processing Record 353: lucea
# Processing Record 354: belushya guba
# Missing field/result...skipping
# Processing Record 355: riverton
# Processing Record 356: ilulissat
# Processing Record 357: baffa
# Processing Record 358: port keats
# Processing Record 359: nalut
# Processing Record 360: wanaka
# Processing Record 361: alofi
# Processing Record 362: pomabamba
# Processing Record 363: mnogovershinnyy
# Processing Record 364: kosh-agach
# Processing Record 365: bastia
# Processing Record 366: gizo
# Processing Record 367: sfantu gheorghe
# Processing Record 368: kulhudhuffushi
# Processing Record 369: coquimbo
# Processing Record 370: dikson
# Processing Record 371: vanavara
# Processing Record 372: manta
# Processing Record 373: la ronge
# Processing Record 374: nome
# Processing Record 375: warrington
# Processing Record 376: neyshabur
# Processing Record 377: poum
# Processing Record 378: nuuk
# Processing Record 379: takaka
# Processing Record 380: merauke
# Processing Record 381: sorong
# Processing Record 382: kavaratti
# Processing Record 383: mehamn
# Processing Record 384: san rafael del sur
# Processing Record 385: amderma
# Missing field/result...skipping
# Processing Record 386: tsihombe
# Missing field/result...skipping
# Processing Record 387: sirajganj
# Processing Record 388: sao geraldo do araguaia
# Processing Record 389: youghal
# Processing Record 390: coulihaut
# Missing field/result...skipping
# Processing Record 391: alugan
# Processing Record 392: aykhal
# Processing Record 393: opuwo
# Processing Record 394: takestan
# Processing Record 395: akwatia
# Processing Record 396: hami
# Processing Record 397: shu
# Processing Record 398: aklavik
# Processing Record 399: traverse city
# Processing Record 400: ostrovnoy
# Processing Record 401: abu dhabi
# Processing Record 402: harnai
# Processing Record 403: coihaique
# Processing Record 404: portland
# Processing Record 405: hueytown
# Processing Record 406: skibbereen
# Processing Record 407: torres
# Processing Record 408: champerico
# Processing Record 409: liverpool
# Processing Record 410: omsukchan
# Processing Record 411: samusu
# Missing field/result...skipping
# Processing Record 412: port hedland
# Processing Record 413: eisenhuttenstadt
# Missing field/result...skipping
# Processing Record 414: port-gentil
# Processing Record 415: mana
# Processing Record 416: shingu
# Processing Record 417: breytovo
# Processing Record 418: tawkar
# Missing field/result...skipping
# Processing Record 419: atbasar
# Processing Record 420: wencheng
# Processing Record 421: pasuruan
# Processing Record 422: barbastro
# Processing Record 423: palabuhanratu
# Missing field/result...skipping
# Processing Record 424: salalah
# Processing Record 425: buala
# Processing Record 426: turukhansk
# Processing Record 427: road town
# Processing Record 428: misratah
# Processing Record 429: toamasina
# Processing Record 430: onufriyivka
# Processing Record 431: vardo
# Processing Record 432: nishihara
# Processing Record 433: catamarca
# Missing field/result...skipping
# Processing Record 434: saldanha
# Processing Record 435: haapiti
# Processing Record 436: yatou
# Processing Record 437: raudeberg
# Processing Record 438: axim
# Processing Record 439: yichang
# Processing Record 440: dorado
# Processing Record 441: suez
# Processing Record 442: shimoda
# Processing Record 443: stornoway
# Missing field/result...skipping
# Processing Record 444: kokkola
# Processing Record 445: marcona
# Missing field/result...skipping
# Processing Record 446: san juan
# Processing Record 447: iskateley
# Processing Record 448: bubaque
# Processing Record 449: chapais
# Processing Record 450: lengshuijiang
# Processing Record 451: san pedro
# Processing Record 452: santa isabel
# Processing Record 453: soure
# Processing Record 454: isangel
# Processing Record 455: eidfjord
# Processing Record 456: husavik
# Processing Record 457: boyolangu
# Processing Record 458: matamoros
# Processing Record 459: prescott
# Processing Record 460: bac lieu
# Missing field/result...skipping
# Processing Record 461: jasper
# Processing Record 462: richards bay
# Processing Record 463: muriti
# Processing Record 464: salamiyah
# Processing Record 465: linjiang
# Processing Record 466: sarangani
# Processing Record 467: leshukonskoye
# Processing Record 468: thiruvananthapuram
# Processing Record 469: batagay
# Processing Record 470: point fortin
# Processing Record 471: guebwiller
# Processing Record 472: luderitz
# Processing Record 473: okato
# Processing Record 474: vestmannaeyjar
# Processing Record 475: tura
# Processing Record 476: duarte
# Processing Record 477: fort nelson
# Processing Record 478: verkhnyaya inta
# Processing Record 479: eagle pass
# Processing Record 480: moirang
# Processing Record 481: mount isa
# Processing Record 482: hervey bay
# Processing Record 483: koshurnikovo
# Processing Record 484: calvinia
# Processing Record 485: ngunguru
# Processing Record 486: princeton
# Processing Record 487: lindsay
# Processing Record 488: kaeo
# Processing Record 489: giyani
# Processing Record 490: henties bay
# Processing Record 491: adrar
# Processing Record 492: djenne
# Processing Record 493: westport
# Processing Record 494: katsuura
# Processing Record 495: port blair
# Processing Record 496: san felipe
# Processing Record 497: luangwa
# Processing Record 498: salunayan
# Processing Record 499: novyy urgal
# Processing Record 500: yuli
# Processing Record 501: cotonou
# Processing Record 502: lavrentiya
# Processing Record 503: ngukurr
# Missing field/result...skipping
# Processing Record 504: palau
# Processing Record 505: boende
# Processing Record 506: kegayli
# Missing field/result...skipping
# Processing Record 507: finschhafen
# Processing Record 508: tubruq
# Missing field/result...skipping
# Processing Record 509: weiser
# Processing Record 510: energetik
# Processing Record 511: ust-kamchatsk
# Missing field/result...skipping
# Processing Record 512: slave lake
# Processing Record 513: nabire
# Processing Record 514: labuan
# Processing Record 515: ouallam
# Processing Record 516: ulyanovo
# Missing field/result...skipping
# Processing Record 517: sinnamary
# Processing Record 518: bababe
# Missing field/result...skipping
# Processing Record 519: umm ruwabah
# Missing field/result...skipping
# Processing Record 520: disna
# Missing field/result...skipping
# Processing Record 521: muisne
# Processing Record 522: fernley
# Processing Record 523: hongjiang
# Processing Record 524: elizabeth city
# Processing Record 525: camopi
# Processing Record 526: nanortalik
# Processing Record 527: inhambane
# Processing Record 528: comodoro rivadavia
# Processing Record 529: christchurch
# Processing Record 530: anadyr
# Processing Record 531: tsiroanomandidy
# Processing Record 532: jalu
# Processing Record 533: galesong
# Processing Record 534: radebeul
# Processing Record 535: deputatskiy
# Processing Record 536: college
# Processing Record 537: farias brito
# Processing Record 538: avera
# Processing Record 539: najran
# Processing Record 540: copperas cove
# Processing Record 541: marawi
# Processing Record 542: taltal
# Processing Record 543: san policarpo
# Processing Record 544: laguna
# Processing Record 545: santa cruz del sur
# Processing Record 546: odate
# Processing Record 547: lakes entrance
# Processing Record 548: egvekinot
# Processing Record 549: krasnyy chikoy
# Processing Record 550: sapa
# Processing Record 551: mahibadhoo
# Processing Record 552: piryetos
# Missing field/result...skipping
# Processing Record 553: lakselv
# Processing Record 554: empalme
# Processing Record 555: sioux lookout
# Processing Record 556: celestun
# Processing Record 557: jian
# Processing Record 558: alamogordo
# Processing Record 559: valparaiso
# Processing Record 560: berlevag
# Processing Record 561: sanhsia
# Missing field/result...skipping
# Processing Record 562: crateus
# Processing Record 563: dusti
# Processing Record 564: bonthe
# Processing Record 565: santa cruz de la palma
# Processing Record 566: kralendijk
# Processing Record 567: tucurui
# Processing Record 568: almaznyy
# Processing Record 569: naze
# Processing Record 570: umm lajj
# Processing Record 571: yulara
# Processing Record 572: eldorado
# Processing Record 573: domoni
# Missing field/result...skipping
# Processing Record 574: troy
# Processing Record 575: yenagoa
# Processing Record 576: lorengau
# Processing Record 577: guasdualito
# Processing Record 578: corowa
# Processing Record 579: aksu
# Processing Record 580: namatanai
# Processing Record 581: nouakchott
# Processing Record 582: hilton head island
# Processing Record 583: rio gallegos
# Processing Record 584: shaunavon
# Processing Record 585: baykit
# Processing Record 586: kununurra
# Processing Record 587: sistranda
# Processing Record 588: quatre cocos
# Processing Record 589: vestmanna
# Processing Record 590: itarema
# Processing Record 591: iqaluit
# Processing Record 592: san quintin
# Processing Record 593: el eden
# Processing Record 594: siguiri
# Processing Record 595: alta floresta
# Processing Record 596: palmer
# Processing Record 597: chaman
# Processing Record 598: te anau
# Processing Record 599: conceicao da barra
# Processing Record 600: antsohihy
# Processing Record 601: vostochnyy
# Processing Record 602: stoyba
# Missing field/result...skipping
# Processing Record 603: sao felix do xingu
# Processing Record 604: broken hill
# Processing Record 605: araceli
# Processing Record 606: ternate
# Processing Record 607: gravdal
# Processing Record 608: bitung
# Processing Record 609: yanam
# Processing Record 610: caohai
# Processing Record 611: seymchan
# Processing Record 612: le bouscat
# Processing Record 613: bilibino

# %% [markdown]
# ## Convert Raw Data into Dataframe
#     Export the city data into a .csv.
#     Display the DataFrame

# %%
df.to_csv(output_data_file,header=True)

# %%
print(df.count())
df.head()
# Out:
# City          613
# Cloudiness    613
# Country       613
# Date          613
# Humidity      613
# Lat           613
# Lng           613
# Max Temp      613
# Wind Speed    613
# dtype: int64
#          City Cloudiness Country        Date Humidity    Lat     Lng Max Temp  \
# 0  oranjemund         44      ZA  1573855926       94 -28.55   16.43     61.5
# 1     mataura         98      NZ  1573855926       93 -46.19  168.86       50
# 2   anklesvar
# 3  vila velha         33      BR  1573855927       69  -3.71   -38.6     82.4
# 4   busselton        100      AU  1573855927       40 -33.64  115.35    66.99
#
#   Wind Speed
# 0      11.41
# 1       5.99
# 2
# 3       8.05
# 4      14.43

# %%
## investigate the data collected.
## see how many cities are missing the field results we are interested in plotting and identify those cities

missing_data_cities=[]
for index, row in df.iterrows():
    if row['Max Temp'] == '' or row['Humidity']== '' or row['Cloudiness']=='' or row['Wind Speed']== '':
        missing_data_cities.append(row['City'])
#         print(index, row)

print(len(missing_data_cities))
print(missing_data_cities)
# Out:
# 62
# ['anklesvar', 'warqla', 'vaitupu', 'saleaula', 'wahran', 'bengkulu', 'abu jubayhah', 'mys shmidta', 'taolanaro', 'toliary', 'illoqqortoormiut', 'samalaeulu', 'krasnoselkup', 'tumannyy', 'meyungs', 'papasquiaro', 'karaul', 'ye', 'matsanga', 'barbar', 'olafsvik', 'ruatoria', 'acarau', 'nizhneyansk', 'sentyabrskiy', 'korla', 'chagda', 'kamenskoye', 'kuche', 'rungata', 'vysokaya gora', 'attawapiskat', 'barentsburg', 'umzimvubu', 'grand river south east', 'orgun', 'karamay', 'jiroft', 'belushya guba', 'amderma', 'tsihombe', 'coulihaut', 'samusu', 'eisenhuttenstadt', 'tawkar', 'palabuhanratu', 'catamarca', 'stornoway', 'marcona', 'bac lieu', 'ngukurr', 'kegayli', 'tubruq', 'ust-kamchatsk', 'ulyanovo', 'bababe', 'umm ruwabah', 'disna', 'piryetos', 'sanhsia', 'domoni', 'stoyba']

# %%
## drop the rows in the dataframe that have missing data fields we are interested in plotting
## use the list of cities missing data to gather a list of their indexs and then drop those rows
row_drops=[]

for i in missing_data_cities:
    row_d=df[df['City']==i].index
    row_drops.append(row_d)
# print(row_drops)

new_df=df.drop(df.index[row_drops])
print(new_df.count())
new_df.head()
# Out:
# City          551
# Cloudiness    551
# Country       551
# Date          551
# Humidity      551
# Lat           551
# Lng           551
# Max Temp      551
# Wind Speed    551
# dtype: int64
#          City Cloudiness Country        Date Humidity    Lat     Lng Max Temp  \
# 0  oranjemund         44      ZA  1573855926       94 -28.55   16.43     61.5
# 1     mataura         98      NZ  1573855926       93 -46.19  168.86       50
# 3  vila velha         33      BR  1573855927       69  -3.71   -38.6     82.4
# 4   busselton        100      AU  1573855927       40 -33.64  115.35    66.99
# 5      barrow         99      AR  1573855342       33 -38.31  -60.23    86.92
#
#   Wind Speed
# 0      11.41
# 1       5.99
# 3       8.05
# 4      14.43
# 5       6.85

# %%
## storing date of data pull from dataframe in variable to use when plotting data
data_pull_date=time.localtime(new_df['Date'][0])
print(data_pull_date)
data_date=f'{data_pull_date[1]}/{data_pull_date[2]}/{data_pull_date[0]}'
print(data_date)
# Out:
# time.struct_time(tm_year=2019, tm_mon=11, tm_mday=15, tm_hour=16, tm_min=12, tm_sec=6, tm_wday=4, tm_yday=319, tm_isdst=0)
# 11/15/2019

# %% [markdown]
# ## Plotting the Data
#     Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
#     Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Max Temp

# %%
x_axis=new_df['Lat']
temp_data=new_df['Max Temp']

plt.scatter(x=x_axis, y=temp_data, marker='o', facecolor='blue', edgecolors='black')
plt.xlim(min(new_df['Lat'])-5,max(new_df['Lat'])+5)
plt.ylim(min(new_df['Max Temp'])-5,max(new_df['Max Temp'])+5)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Fahrenheit)")
plt.title(f"City Latitude vs. Max Temperature {data_date}")
plt.grid()
plt.savefig('output_data/LatVsTemp.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity

# %%
hum_data=new_df['Humidity']

plt.scatter(x=x_axis, y=hum_data, marker='o', facecolor='blue', edgecolors='black')
plt.xlim(min(new_df['Lat'])-5,max(new_df['Lat'])+5)
plt.ylim(min(new_df['Humidity'])-5,max(new_df['Humidity'])+5)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity {data_date}")
plt.grid()
plt.savefig('output_data/LatVsHum.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness

# %%
cld_data=new_df['Cloudiness']

plt.scatter(x=x_axis, y=cld_data, marker='o', facecolor='blue', edgecolors='black')
plt.xlim(min(new_df['Lat'])-5,max(new_df['Lat'])+5)
plt.ylim(min(new_df['Cloudiness'])-5,max(new_df['Cloudiness'])+5)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs. Cloudiness {data_date}")
plt.grid()
plt.savefig('output_data/LatVsClouds.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed

# %%
wsp_data=new_df['Wind Speed']

plt.scatter(x=x_axis, y=wsp_data, marker='o', facecolor='blue', edgecolors='black')
plt.xlim(min(new_df['Lat'])-2,max(new_df['Lat'])+2)
plt.ylim(min(new_df['Wind Speed'])-2,max(new_df['Wind Speed'])+2)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs. Wind Speed {data_date}")
plt.grid()
plt.savefig('output_data/LatVsWind.png')
plt.show()

# %%
new_df.head()
# Out:
#          City Cloudiness Country        Date Humidity    Lat     Lng Max Temp  \
# 0  oranjemund         44      ZA  1573855926       94 -28.55   16.43     61.5
# 1     mataura         98      NZ  1573855926       93 -46.19  168.86       50
# 3  vila velha         33      BR  1573855927       69  -3.71   -38.6     82.4
# 4   busselton        100      AU  1573855927       40 -33.64  115.35    66.99
# 5      barrow         99      AR  1573855342       33 -38.31  -60.23    86.92
#
#   Wind Speed
# 0      11.41
# 1       5.99
# 3       8.05
# 4      14.43
# 5       6.85

# %%
## binning data to further investigate results by latitude ranges
bins=[-90,-45,0,45,90]
bin_name=['far_west','west','east','far_east']
new_df['Lat_Ranges']=pd.cut(new_df['Lat'],bins,labels=bin_name)
new_df.head()
# Out:
#          City Cloudiness Country        Date Humidity    Lat     Lng Max Temp  \
# 0  oranjemund         44      ZA  1573855926       94 -28.55   16.43     61.5
# 1     mataura         98      NZ  1573855926       93 -46.19  168.86       50
# 3  vila velha         33      BR  1573855927       69  -3.71   -38.6     82.4
# 4   busselton        100      AU  1573855927       40 -33.64  115.35    66.99
# 5      barrow         99      AR  1573855342       33 -38.31  -60.23    86.92
#
#   Wind Speed Lat_Ranges
# 0      11.41       west
# 1       5.99   far_west
# 3       8.05       west
# 4      14.43       west
# 5       6.85       west

# %%
group_df=new_df.groupby(['Lat_Ranges'])
group_df['City'].count()
# Out:
# Lat_Ranges
# far_west     11
# west        165
# east        234
# far_east    141
# Name: City, dtype: int64

# %%
new_df['Max Temp']=pd.to_numeric(df['Max Temp'])
group_df=new_df.groupby(['Lat_Ranges'])
group_df['Max Temp'].mean()
# Out:
# Lat_Ranges
# far_west    57.085455
# west        73.441818
# east        65.234316
# far_east    19.538227
# Name: Max Temp, dtype: float64

# %%
new_df['Humidity']=pd.to_numeric(df['Humidity'])
group_df=new_df.groupby(['Lat_Ranges'])
group_df['Humidity'].mean()
# Out:
# Lat_Ranges
# far_west    62.000000
# west        70.521212
# east        65.354701
# far_east    81.113475
# Name: Humidity, dtype: float64

# %%
new_df['Cloudiness']=pd.to_numeric(df['Cloudiness'])
group_df=new_df.groupby(['Lat_Ranges'])
group_df['Cloudiness'].mean()
# Out:
# Lat_Ranges
# far_west    64.818182
# west        49.945455
# east        43.944444
# far_east    66.723404
# Name: Cloudiness, dtype: float64

# %%
new_df['Wind Speed']=pd.to_numeric(df['Wind Speed'])
group_df=new_df.groupby(['Lat_Ranges'])
group_df['Wind Speed'].mean()
# Out:
# Lat_Ranges
# far_west    15.582727
# west         8.446848
# east         6.767179
# far_east     9.682766
# Name: Wind Speed, dtype: float64

# %% [markdown]
# ## My Observations:
#
# - Based on the City Latitude vs. Max Temperature (fahrenheit) data results, it appears that cities with latitudes West of the equator (latitude is 0 to -90) have higher max temperatures than cities with latitudes east of the equator (latitude is 0 to 90).
# - Based on the City Latitude vs. Humidity (%) data results, it appears that cities to the far East of the equator (latitude is 45 to 90) tend to have higher humidity percentages.
# - Based on the City Latitude vs. Cloudiness (%) data results, it appears that cities closer to the equator on both the East and the West (latitude is somewhere between -45 and 45) have lower percentages of clouds. Cities further from the equator (latitude is ether -90 to -45 (West) or 45 to 90 (East)) tend to have higher percentages of clouds than those closer to the equator.
