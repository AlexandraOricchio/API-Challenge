# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os 

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = os.path.join("output_data","cities.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ## Perform API Calls
#     Perform a weather check on each city using a series of successive API calls.
#     Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
## Create dataframe of cities in list with empty columns for data
df=pd.DataFrame(cities)
df=df.rename(columns={0:'City'})
df['Cloudiness']=''
df['Country']=''
df['Date']=''
df['Humidity']=''
df['Lat']=''
df['Lng']=''
df['Max Temp']=''
df['Wind Speed']=''
print(df.shape)
df.head()
# Out:
# (626, 9)
#              City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0        zyryanka
# 1          dikson
# 2          hwange
# 3  ribeira grande
# 4          hasaki

# %%
## create base url and parameters
base_url="http://api.openweathermap.org/data/2.5/weather?"
params={"units":"imperial",
       "APPID":api_key}

# %%
count=1

for index, row in df.iterrows():
    
    # get city from dataframe
    city_name=row['City']
    
    # add new key to params for query search by city name
    params['q']=city_name
    
    # assemble url and make api request
    response=requests.get(base_url,params=params).json()
    
    try:
        print(f'Processing Record {count}: {city_name}')
    
        df.loc[index, 'Cloudiness']=response['clouds']['all']
        df.loc[index, 'Country']=response['sys']['country']
        df.loc[index, 'Date']=response['dt']
        df.loc[index,'Humidity']=response['main']['humidity']
        df.loc[index,'Lat']=response['coord']['lat']
        df.loc[index,'Lng']=response['coord']['lon']
        df.loc[index,'Max Temp']=response['main']['temp_max']
        df.loc[index,'Wind Speed']=response['wind']['speed']
    except(KeyError):
        print("Missing field/result...skipping")
    
    count=count+1
# Out:
# Processing Record 1: zyryanka
# Processing Record 2: dikson
# Processing Record 3: hwange
# Processing Record 4: ribeira grande
# Processing Record 5: hasaki
# Processing Record 6: avarua
# Processing Record 7: new norfolk
# Processing Record 8: yellowknife
# Processing Record 9: rancho palos verdes
# Processing Record 10: mataura
# Processing Record 11: niksar
# Processing Record 12: madimba
# Processing Record 13: cape town
# Processing Record 14: dargaville
# Processing Record 15: abu samrah
# Processing Record 16: rikitea
# Processing Record 17: talara
# Processing Record 18: ushuaia
# Processing Record 19: east london
# Processing Record 20: mys shmidta
# Missing field/result...skipping
# Processing Record 21: puerto ayora
# Processing Record 22: arraial do cabo
# Processing Record 23: soure
# Processing Record 24: honiton
# Processing Record 25: hobart
# Processing Record 26: sentyabrskiy
# Missing field/result...skipping
# Processing Record 27: coahuayana
# Processing Record 28: nanortalik
# Processing Record 29: margate
# Processing Record 30: attawapiskat
# Missing field/result...skipping
# Processing Record 31: hithadhoo
# Processing Record 32: cherskiy
# Processing Record 33: bengkulu
# Missing field/result...skipping
# Processing Record 34: denpasar
# Processing Record 35: christchurch
# Processing Record 36: souillac
# Processing Record 37: vaini
# Processing Record 38: atuona
# Processing Record 39: korla
# Missing field/result...skipping
# Processing Record 40: vestmannaeyjar
# Processing Record 41: nizhneyansk
# Missing field/result...skipping
# Processing Record 42: sitka
# Processing Record 43: waingapu
# Processing Record 44: acapulco
# Processing Record 45: coquimbo
# Processing Record 46: hilo
# Processing Record 47: hermanus
# Processing Record 48: burns lake
# Processing Record 49: bukama
# Processing Record 50: jeremoabo
# Processing Record 51: albany
# Processing Record 52: butaritari
# Processing Record 53: namibe
# Processing Record 54: pevek
# Processing Record 55: talnakh
# Processing Record 56: bluff
# Processing Record 57: punta arenas
# Processing Record 58: ouango
# Processing Record 59: georgetown
# Processing Record 60: thompson
# Processing Record 61: lasa
# Processing Record 62: saldanha
# Processing Record 63: cabo san lucas
# Processing Record 64: khandyga
# Processing Record 65: upernavik
# Processing Record 66: kiruna
# Processing Record 67: touros
# Processing Record 68: chokurdakh
# Processing Record 69: ugoofaaru
# Processing Record 70: amderma
# Missing field/result...skipping
# Processing Record 71: marcona
# Missing field/result...skipping
# Processing Record 72: kelvington
# Processing Record 73: say
# Processing Record 74: macau
# Processing Record 75: aklavik
# Processing Record 76: tuktoyaktuk
# Processing Record 77: busselton
# Processing Record 78: kavieng
# Processing Record 79: barrow
# Processing Record 80: taua
# Processing Record 81: grindavik
# Processing Record 82: jamestown
# Processing Record 83: rondonopolis
# Processing Record 84: ahualulco
# Processing Record 85: san carlos de bariloche
# Processing Record 86: bubaque
# Processing Record 87: ayios kirikos
# Missing field/result...skipping
# Processing Record 88: tautira
# Processing Record 89: yenagoa
# Processing Record 90: bethel
# Processing Record 91: chake chake
# Processing Record 92: zeya
# Processing Record 93: mehriz
# Processing Record 94: lompoc
# Processing Record 95: taolanaro
# Missing field/result...skipping
# Processing Record 96: acajutla
# Processing Record 97: kodiak
# Processing Record 98: vaitupu
# Missing field/result...skipping
# Processing Record 99: anito
# Processing Record 100: tura
# Processing Record 101: ponta do sol
# Processing Record 102: nishihara
# Processing Record 103: saint-philippe
# Processing Record 104: husavik
# Processing Record 105: katima mulilo
# Processing Record 106: asau
# Missing field/result...skipping
# Processing Record 107: tidore
# Missing field/result...skipping
# Processing Record 108: yuzhno-yeniseyskiy
# Missing field/result...skipping
# Processing Record 109: castro
# Processing Record 110: hirara
# Processing Record 111: akyab
# Missing field/result...skipping
# Processing Record 112: hambantota
# Processing Record 113: kruisfontein
# Processing Record 114: saint anthony
# Processing Record 115: aitape
# Processing Record 116: kaitangata
# Processing Record 117: san jose
# Processing Record 118: whyalla
# Processing Record 119: qaanaaq
# Processing Record 120: northam
# Processing Record 121: puerto narino
# Processing Record 122: nowy sacz
# Processing Record 123: manta
# Processing Record 124: hirado
# Processing Record 125: krasnokamensk
# Processing Record 126: rabo de peixe
# Processing Record 127: galesong
# Processing Record 128: cidreira
# Processing Record 129: lulea
# Processing Record 130: provideniya
# Processing Record 131: jalu
# Processing Record 132: fayaoue
# Processing Record 133: ajdabiya
# Processing Record 134: portland
# Processing Record 135: igrim
# Processing Record 136: toora-khem
# Processing Record 137: nador
# Processing Record 138: buluang
# Processing Record 139: bambous virieux
# Processing Record 140: saint george
# Processing Record 141: emirdag
# Processing Record 142: zhigansk
# Processing Record 143: chuy
# Processing Record 144: lokosovo
# Processing Record 145: bafoulabe
# Processing Record 146: pangnirtung
# Processing Record 147: mangrol
# Processing Record 148: linhares
# Processing Record 149: port alfred
# Processing Record 150: victoria
# Processing Record 151: tongliao
# Processing Record 152: barentsburg
# Missing field/result...skipping
# Processing Record 153: cam ranh
# Processing Record 154: saint-pierre
# Processing Record 155: salalah
# Processing Record 156: salinas
# Processing Record 157: kilindoni
# Processing Record 158: bredasdorp
# Processing Record 159: tual
# Processing Record 160: avera
# Processing Record 161: riyadh
# Processing Record 162: san juan bautista
# Processing Record 163: zermatt
# Processing Record 164: saskylakh
# Processing Record 165: mananjary
# Processing Record 166: garmsar
# Processing Record 167: belushya guba
# Missing field/result...skipping
# Processing Record 168: badamdar
# Processing Record 169: maracacume
# Processing Record 170: kapaa
# Processing Record 171: airai
# Processing Record 172: buraydah
# Processing Record 173: nouadhibou
# Processing Record 174: bambanglipuro
# Processing Record 175: korop
# Processing Record 176: lebu
# Processing Record 177: kieta
# Processing Record 178: port-gentil
# Processing Record 179: tasiilaq
# Processing Record 180: san cristobal
# Processing Record 181: aksu
# Processing Record 182: imeni stepana razina
# Processing Record 183: mar del plata
# Processing Record 184: beyla
# Processing Record 185: andra
# Processing Record 186: clyde river
# Processing Record 187: mount gambier
# Processing Record 188: iqaluit
# Processing Record 189: faanui
# Processing Record 190: constitucion
# Processing Record 191: maniitsoq
# Processing Record 192: torbay
# Processing Record 193: tiznit
# Processing Record 194: port lincoln
# Processing Record 195: taksimo
# Processing Record 196: lavrentiya
# Processing Record 197: ouadda
# Processing Record 198: dekar
# Processing Record 199: leeton
# Processing Record 200: zolotinka
# Missing field/result...skipping
# Processing Record 201: sao joao del rei
# Processing Record 202: bereda
# Processing Record 203: kitui
# Processing Record 204: siyabuswa
# Processing Record 205: marzuq
# Processing Record 206: bingol
# Processing Record 207: alegrete
# Processing Record 208: qandala
# Processing Record 209: qaqortoq
# Processing Record 210: nome
# Processing Record 211: kailua
# Processing Record 212: vardo
# Processing Record 213: chapais
# Processing Record 214: berlevag
# Processing Record 215: yumen
# Processing Record 216: lagoa
# Processing Record 217: port arthur
# Processing Record 218: saleaula
# Missing field/result...skipping
# Processing Record 219: beyneu
# Processing Record 220: nichinan
# Processing Record 221: escarcega
# Processing Record 222: grand river south east
# Missing field/result...skipping
# Processing Record 223: roald
# Processing Record 224: camacha
# Processing Record 225: mounana
# Processing Record 226: khatanga
# Processing Record 227: tinqueux
# Processing Record 228: cayenne
# Processing Record 229: kudahuvadhoo
# Processing Record 230: meulaboh
# Processing Record 231: sakakah
# Missing field/result...skipping
# Processing Record 232: moosomin
# Processing Record 233: weligama
# Processing Record 234: bowen
# Processing Record 235: illoqqortoormiut
# Missing field/result...skipping
# Processing Record 236: tiksi
# Processing Record 237: varvoru
# Processing Record 238: sungairaya
# Processing Record 239: sontra
# Processing Record 240: ahuimanu
# Processing Record 241: mercedes
# Processing Record 242: san ignacio
# Processing Record 243: sao joao da barra
# Processing Record 244: mon
# Processing Record 245: bonthe
# Processing Record 246: quelimane
# Processing Record 247: nabire
# Processing Record 248: san jeronimo
# Processing Record 249: esperance
# Processing Record 250: beloha
# Processing Record 251: muros
# Processing Record 252: axim
# Processing Record 253: semey
# Processing Record 254: makakilo city
# Processing Record 255: tevaitoa
# Processing Record 256: silver city
# Processing Record 257: berezovka
# Processing Record 258: sisimiut
# Processing Record 259: ostrovnoy
# Processing Record 260: bathsheba
# Processing Record 261: port hardy
# Processing Record 262: samana
# Processing Record 263: sao miguel do oeste
# Missing field/result...skipping
# Processing Record 264: guerrero negro
# Processing Record 265: komsomolskiy
# Processing Record 266: havre-saint-pierre
# Processing Record 267: dongkan
# Processing Record 268: kupang
# Processing Record 269: ginda
# Processing Record 270: taunggyi
# Processing Record 271: asfi
# Missing field/result...skipping
# Processing Record 272: samarai
# Processing Record 273: chilca
# Processing Record 274: kirando
# Processing Record 275: tabory
# Processing Record 276: xichang
# Processing Record 277: baringo
# Processing Record 278: pabellon de arteaga
# Missing field/result...skipping
# Processing Record 279: longyearbyen
# Processing Record 280: laguna
# Processing Record 281: homer
# Processing Record 282: seybaplaya
# Processing Record 283: along
# Processing Record 284: sechura
# Processing Record 285: linxia
# Processing Record 286: half moon bay
# Processing Record 287: alfenas
# Processing Record 288: geraldton
# Processing Record 289: sahrak
# Missing field/result...skipping
# Processing Record 290: grand island
# Processing Record 291: gamba
# Processing Record 292: tumannyy
# Missing field/result...skipping
# Processing Record 293: pisco
# Processing Record 294: ulladulla
# Processing Record 295: kendari
# Processing Record 296: codrington
# Processing Record 297: xuddur
# Processing Record 298: lolua
# Missing field/result...skipping
# Processing Record 299: kloulklubed
# Processing Record 300: umzimvubu
# Missing field/result...skipping
# Processing Record 301: veseloyarsk
# Processing Record 302: siavonga
# Processing Record 303: warqla
# Missing field/result...skipping
# Processing Record 304: huarmey
# Processing Record 305: belmonte
# Processing Record 306: beringovskiy
# Processing Record 307: longlac
# Missing field/result...skipping
# Processing Record 308: faya
# Processing Record 309: labytnangi
# Processing Record 310: sibolga
# Processing Record 311: waipawa
# Processing Record 312: atherton
# Processing Record 313: betioky
# Missing field/result...skipping
# Processing Record 314: bandarbeyla
# Processing Record 315: klamath falls
# Processing Record 316: whitehorse
# Processing Record 317: goure
# Processing Record 318: maningrida
# Processing Record 319: ardakan
# Processing Record 320: kemi
# Processing Record 321: mombetsu
# Processing Record 322: ulagan
# Processing Record 323: taoudenni
# Processing Record 324: ereymentau
# Processing Record 325: uwajima
# Processing Record 326: urzhum
# Processing Record 327: hami
# Processing Record 328: ust-maya
# Processing Record 329: port augusta
# Processing Record 330: carutapera
# Processing Record 331: the valley
# Processing Record 332: narsaq
# Processing Record 333: monte alegre
# Processing Record 334: toliary
# Missing field/result...skipping
# Processing Record 335: la palma
# Processing Record 336: polovinnoye
# Processing Record 337: aljezur
# Processing Record 338: sept-iles
# Processing Record 339: samusu
# Missing field/result...skipping
# Processing Record 340: ossora
# Processing Record 341: nuuk
# Processing Record 342: te anau
# Processing Record 343: phan rang
# Missing field/result...skipping
# Processing Record 344: norman wells
# Processing Record 345: nikolskoye
# Processing Record 346: santimbru
# Processing Record 347: vagur
# Processing Record 348: fukue
# Processing Record 349: ketchikan
# Processing Record 350: tabarqah
# Missing field/result...skipping
# Processing Record 351: fare
# Processing Record 352: saint-lo
# Processing Record 353: college
# Processing Record 354: namatanai
# Processing Record 355: shelburne
# Processing Record 356: chico
# Processing Record 357: ormara
# Processing Record 358: sarangani
# Processing Record 359: pavlovsk
# Processing Record 360: nevsehir
# Processing Record 361: muroto
# Processing Record 362: kathu
# Processing Record 363: ahome
# Processing Record 364: contai
# Processing Record 365: bermejo
# Processing Record 366: novyy karachay
# Processing Record 367: ust-tsilma
# Processing Record 368: pokaran
# Processing Record 369: tashtyp
# Processing Record 370: severo-kurilsk
# Processing Record 371: mackenzie
# Processing Record 372: broome
# Processing Record 373: hualmay
# Processing Record 374: keta
# Processing Record 375: celarevo
# Processing Record 376: alugan
# Processing Record 377: hay river
# Processing Record 378: asyut
# Processing Record 379: satis
# Processing Record 380: pulsano
# Processing Record 381: omboue
# Processing Record 382: sabang
# Processing Record 383: vostok
# Processing Record 384: klaksvik
# Processing Record 385: shurugwi
# Processing Record 386: sao filipe
# Processing Record 387: palabuhanratu
# Missing field/result...skipping
# Processing Record 388: padang
# Processing Record 389: puerto cortes
# Missing field/result...skipping
# Processing Record 390: buchanan
# Processing Record 391: erzin
# Processing Record 392: chagda
# Missing field/result...skipping
# Processing Record 393: kajiado
# Processing Record 394: luanda
# Processing Record 395: vallenar
# Processing Record 396: hede
# Processing Record 397: newport
# Processing Record 398: goreloye
# Processing Record 399: meadow lake
# Processing Record 400: arroyo
# Processing Record 401: kuala krai
# Missing field/result...skipping
# Processing Record 402: odesskoye
# Processing Record 403: mahebourg
# Processing Record 404: nakanojo
# Processing Record 405: luderitz
# Processing Record 406: port elizabeth
# Processing Record 407: santa barbara
# Processing Record 408: aborlan
# Processing Record 409: asasa
# Processing Record 410: luga
# Processing Record 411: sivaki
# Processing Record 412: dunedin
# Processing Record 413: cerrito
# Processing Record 414: huanren
# Processing Record 415: katsuura
# Processing Record 416: sukhodol
# Processing Record 417: banda aceh
# Processing Record 418: svetlaya
# Processing Record 419: sale
# Processing Record 420: huron
# Processing Record 421: sambava
# Processing Record 422: wana
# Processing Record 423: belousovka
# Processing Record 424: san rafael
# Processing Record 425: isangel
# Processing Record 426: eskasem
# Missing field/result...skipping
# Processing Record 427: lewiston
# Processing Record 428: tignere
# Processing Record 429: kukushtan
# Processing Record 430: borlange
# Missing field/result...skipping
# Processing Record 431: la asuncion
# Processing Record 432: guia de isora
# Processing Record 433: phalombe
# Processing Record 434: atar
# Processing Record 435: kuhestan
# Missing field/result...skipping
# Processing Record 436: tomatlan
# Processing Record 437: darovskoy
# Processing Record 438: preobrazheniye
# Processing Record 439: kosh
# Missing field/result...skipping
# Processing Record 440: registro
# Processing Record 441: itamaraca
# Processing Record 442: flin flon
# Processing Record 443: banyo
# Processing Record 444: vila franca do campo
# Processing Record 445: itoman
# Processing Record 446: sorland
# Processing Record 447: adre
# Processing Record 448: bilma
# Processing Record 449: nantucket
# Processing Record 450: carnarvon
# Processing Record 451: lima
# Processing Record 452: mana
# Processing Record 453: kharovsk
# Processing Record 454: zambezi
# Processing Record 455: leningradskiy
# Processing Record 456: bourail
# Processing Record 457: saint-joseph
# Processing Record 458: port hedland
# Processing Record 459: urdzhar
# Missing field/result...skipping
# Processing Record 460: jinxiang
# Processing Record 461: surt
# Processing Record 462: campbell river
# Processing Record 463: dhidhdhoo
# Processing Record 464: loubomo
# Missing field/result...skipping
# Processing Record 465: fontenay-le-comte
# Processing Record 466: nuevo progreso
# Processing Record 467: storsteinnes
# Processing Record 468: groningen
# Processing Record 469: port keats
# Processing Record 470: waddan
# Processing Record 471: sorvag
# Missing field/result...skipping
# Processing Record 472: hofn
# Processing Record 473: pacific grove
# Processing Record 474: carson city
# Processing Record 475: nakhon thai
# Processing Record 476: yining
# Processing Record 477: alyangula
# Processing Record 478: doctor pedro p. pena
# Missing field/result...skipping
# Processing Record 479: karakulino
# Processing Record 480: sukumo
# Processing Record 481: paramonga
# Processing Record 482: grevena
# Processing Record 483: rupert
# Processing Record 484: manaus
# Processing Record 485: coihaique
# Processing Record 486: iracoubo
# Processing Record 487: marrakesh
# Processing Record 488: kantang
# Processing Record 489: paamiut
# Processing Record 490: raymond
# Processing Record 491: melnikovo
# Processing Record 492: port blair
# Processing Record 493: soyo
# Processing Record 494: kraslava
# Processing Record 495: havelock
# Processing Record 496: mogadishu
# Processing Record 497: arani
# Processing Record 498: kozluk
# Processing Record 499: wulanhaote
# Missing field/result...skipping
# Processing Record 500: basarabeasca
# Processing Record 501: deputatskiy
# Processing Record 502: kodar
# Processing Record 503: kahului
# Processing Record 504: gidole
# Processing Record 505: diapaga
# Processing Record 506: port macquarie
# Processing Record 507: xining
# Processing Record 508: vila velha
# Processing Record 509: manaure
# Processing Record 510: maneromango
# Processing Record 511: ilulissat
# Processing Record 512: maromitsa
# Processing Record 513: noyabrsk
# Processing Record 514: vaasa
# Processing Record 515: gorontalo
# Processing Record 516: tilichiki
# Processing Record 517: antofagasta
# Processing Record 518: kungurtug
# Processing Record 519: kamenka
# Processing Record 520: oktyabrskoye
# Processing Record 521: ballina
# Processing Record 522: san ramon
# Processing Record 523: shenjiamen
# Processing Record 524: rafsanjan
# Processing Record 525: mastung
# Processing Record 526: ancud
# Processing Record 527: road town
# Processing Record 528: vestmanna
# Processing Record 529: belaya gora
# Processing Record 530: shrigonda
# Processing Record 531: piacabucu
# Processing Record 532: ekhabi
# Processing Record 533: bongandanga
# Processing Record 534: sinnamary
# Processing Record 535: lerwick
# Processing Record 536: scharding
# Processing Record 537: akcakoca
# Processing Record 538: goderich
# Processing Record 539: plettenberg bay
# Processing Record 540: santa marta
# Processing Record 541: howick
# Processing Record 542: pangkalanbuun
# Processing Record 543: harper
# Processing Record 544: datong
# Processing Record 545: sayat
# Processing Record 546: dhamtari
# Processing Record 547: eldikan
# Missing field/result...skipping
# Processing Record 548: el retorno
# Processing Record 549: luxor
# Processing Record 550: itarema
# Processing Record 551: caravelas
# Processing Record 552: mahajanga
# Processing Record 553: ponta delgada
# Processing Record 554: vanimo
# Processing Record 555: chumikan
# Processing Record 556: huambo
# Processing Record 557: venezuela
# Processing Record 558: aksarka
# Processing Record 559: gonbad-e qabus
# Processing Record 560: havoysund
# Processing Record 561: fuerte olimpo
# Processing Record 562: limbuhan
# Processing Record 563: kandrian
# Processing Record 564: mananara
# Missing field/result...skipping
# Processing Record 565: hamilton
# Processing Record 566: agua buena
# Processing Record 567: robertsport
# Processing Record 568: nakamura
# Processing Record 569: wah
# Missing field/result...skipping
# Processing Record 570: ijuin
# Processing Record 571: stolin
# Processing Record 572: dingle
# Processing Record 573: villa carlos paz
# Processing Record 574: nikko
# Processing Record 575: serra talhada
# Processing Record 576: halifax
# Processing Record 577: turukhansk
# Processing Record 578: selikhino
# Processing Record 579: paranaiba
# Processing Record 580: pyshma
# Processing Record 581: emerald
# Processing Record 582: biltine
# Processing Record 583: comodoro rivadavia
# Processing Record 584: srednekolymsk
# Processing Record 585: tiarei
# Processing Record 586: moerai
# Processing Record 587: henties bay
# Processing Record 588: mount isa
# Processing Record 589: rundu
# Processing Record 590: la ronge
# Processing Record 591: uray
# Processing Record 592: huilong
# Processing Record 593: malumfashi
# Processing Record 594: hobyo
# Processing Record 595: dovers
# Processing Record 596: botshabelo
# Processing Record 597: barbar
# Missing field/result...skipping
# Processing Record 598: ravenna
# Processing Record 599: thinadhoo
# Processing Record 600: manadhoo
# Processing Record 601: naze
# Processing Record 602: broken hill
# Processing Record 603: tempio pausania
# Processing Record 604: tokur
# Processing Record 605: rypefjord
# Processing Record 606: fuxin
# Processing Record 607: alice springs
# Processing Record 608: yerbogachen
# Processing Record 609: dwarka
# Processing Record 610: sterling
# Processing Record 611: stromness
# Processing Record 612: rocha
# Processing Record 613: aketi
# Processing Record 614: yar-sale
# Processing Record 615: sann
# Processing Record 616: cordoba
# Processing Record 617: stokmarknes
# Processing Record 618: urulga
# Missing field/result...skipping
# Processing Record 619: diebougou
# Processing Record 620: progreso
# Processing Record 621: xuanhua
# Processing Record 622: jerantut
# Processing Record 623: grand gaube
# Processing Record 624: tuatapere
# Processing Record 625: burnie
# Processing Record 626: safonovo

# %% [markdown]
# ## Convert Raw Data into Dataframe
#     Export the city data into a .csv.
#     Display the DataFrame

# %%
df.to_csv(output_data_file,header=True)

# %%
print(df.count())
df.head()
# Out:
# City          626
# Cloudiness    626
# Country       626
# Date          626
# Humidity      626
# Lat           626
# Lng           626
# Max Temp      626
# Wind Speed    626
# dtype: int64
#              City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0        zyryanka         80      RU  1573664923       97  65.73  150.89
# 1          dikson         82      RU  1573664923       95  73.51   80.55
# 2          hwange        100      ZW  1573664923       70 -18.35    26.5
# 3  ribeira grande         20      PT  1573664924       59  38.52   -28.7
# 4          hasaki         75      JP  1573664924       82  35.73  140.83
#
#   Max Temp Wind Speed
# 0    -0.58       3.09
# 1     9.66       6.11
# 2    75.76       5.35
# 3     66.2      18.34
# 4     62.6       9.17

# %%
## investigate the data collected.
## see how many cities are missing the field results we are interested in plotting and identify those cities

missing_data_cities=[]
for index, row in df.iterrows():
    if row['Max Temp'] == '' or row['Humidity']== '' or row['Cloudiness']=='' or row['Wind Speed']== '':
        missing_data_cities.append(row['City'])
#         print(index, row)

print(len(missing_data_cities))
print(missing_data_cities)
# Out:
# 54
# ['mys shmidta', 'sentyabrskiy', 'attawapiskat', 'bengkulu', 'korla', 'nizhneyansk', 'amderma', 'marcona', 'ayios kirikos', 'taolanaro', 'vaitupu', 'asau', 'tidore', 'yuzhno-yeniseyskiy', 'akyab', 'barentsburg', 'belushya guba', 'zolotinka', 'saleaula', 'grand river south east', 'sakakah', 'illoqqortoormiut', 'sao miguel do oeste', 'asfi', 'pabellon de arteaga', 'sahrak', 'tumannyy', 'lolua', 'umzimvubu', 'warqla', 'longlac', 'betioky', 'toliary', 'samusu', 'phan rang', 'tabarqah', 'palabuhanratu', 'puerto cortes', 'chagda', 'kuala krai', 'eskasem', 'borlange', 'kuhestan', 'kosh', 'urdzhar', 'loubomo', 'sorvag', 'doctor pedro p. pena', 'wulanhaote', 'eldikan', 'mananara', 'wah', 'barbar', 'urulga']

# %%
## drop the rows in the dataframe that have missing data fields we are interested in plotting
## use the list of cities missing data to gather a list of their indexs and then drop those rows
row_drops=[]

for i in missing_data_cities:
    row_d=df[df['City']==i].index
    row_drops.append(row_d)
# print(row_drops)

new_df=df.drop(df.index[row_drops])
print(new_df.count())
new_df.head()
# Out:
# City          572
# Cloudiness    572
# Country       572
# Date          572
# Humidity      572
# Lat           572
# Lng           572
# Max Temp      572
# Wind Speed    572
# dtype: int64
#              City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0        zyryanka         80      RU  1573664923       97  65.73  150.89
# 1          dikson         82      RU  1573664923       95  73.51   80.55
# 2          hwange        100      ZW  1573664923       70 -18.35    26.5
# 3  ribeira grande         20      PT  1573664924       59  38.52   -28.7
# 4          hasaki         75      JP  1573664924       82  35.73  140.83
#
#   Max Temp Wind Speed
# 0    -0.58       3.09
# 1     9.66       6.11
# 2    75.76       5.35
# 3     66.2      18.34
# 4     62.6       9.17

# %%
## storing date of data pull from dataframe in variable to use when plotting data
data_pull_date=time.localtime(new_df['Date'][0])
print(data_pull_date)
data_date=f'{data_pull_date[1]}/{data_pull_date[2]}/{data_pull_date[0]}'
print(data_date)
# Out:
# time.struct_time(tm_year=2019, tm_mon=11, tm_mday=13, tm_hour=11, tm_min=8, tm_sec=43, tm_wday=2, tm_yday=317, tm_isdst=0)
# 11/13/2019

# %% [markdown]
# ## Plotting the Data
#     Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
#     Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Max Temp

# %%
x_axis=new_df['Lat']
temp_data=new_df['Max Temp']

plt.scatter(x=x_axis, y=temp_data, marker='o', facecolor='blue', edgecolors='black')
plt.xlim(min(new_df['Lat'])-10,max(new_df['Lat'])+10)
plt.ylim(min(new_df['Max Temp'])-10,max(new_df['Max Temp'])+10)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Fahrenheit)")
plt.title(f"City Latitude vs. Max Temperature {data_date}")
plt.grid()
plt.savefig('output_data/LatVsTemp.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity

# %%
hum_data=new_df['Humidity']

plt.scatter(x=x_axis, y=hum_data, marker='o', facecolor='blue', edgecolors='black')
plt.xlim(min(new_df['Lat'])-10,max(new_df['Lat'])+10)
plt.ylim(min(new_df['Humidity'])-10,max(new_df['Humidity'])+10)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity {data_date}")
plt.grid()
plt.savefig('output_data/LatVsHum.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness

# %%
cld_data=new_df['Cloudiness']

plt.scatter(x=x_axis, y=cld_data, marker='o', facecolor='blue', edgecolors='black')
plt.xlim(min(new_df['Lat'])-10,max(new_df['Lat'])+10)
plt.ylim(min(new_df['Cloudiness'])-10,max(new_df['Cloudiness'])+10)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs. Cloudiness {data_date}")
plt.grid()
plt.savefig('output_data/LatVsClouds.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed

# %%
wsp_data=new_df['Wind Speed']

plt.scatter(x=x_axis, y=wsp_data, marker='o', facecolor='blue', edgecolors='black')
plt.xlim(min(new_df['Lat'])-10,max(new_df['Lat'])+10)
plt.ylim(min(new_df['Wind Speed'])-10,max(new_df['Wind Speed'])+10)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs. Wind Speed {data_date}")
plt.grid()
plt.savefig('output_data/LatVsWind.png')
plt.show()

# %% [markdown]
# ## My Observations:
