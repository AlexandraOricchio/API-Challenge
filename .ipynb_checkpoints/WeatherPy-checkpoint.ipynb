# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os 

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = os.path.join("output_data","cities.csv")

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ## Perform API Calls
#     Perform a weather check on each city using a series of successive API calls.
#     Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
## Create dataframe of cities in list with empty columns for data
df=pd.DataFrame(cities)
df=df.rename(columns={0:'City'})
df['Cloudiness']=''
df['Country']=''
df['Date']=''
df['Humidity']=''
df['Lat']=''
df['Lng']=''
df['Max Temp']=''
df['Wind Speed']=''
print(df.shape)
df.head()
# Out:
# (608, 9)
#             City Cloudiness Country Date Humidity Lat Lng Max Temp Wind Speed
# 0   kruisfontein
# 1        waipawa
# 2      mouzakion
# 3         castro
# 4  manoel urbano

# %%
## create base url and parameters
base_url="http://api.openweathermap.org/data/2.5/weather?"
params={"units":"imperial",
       "APPID":api_key}

# %%
count=1

for index, row in df.iterrows():
    
    # get city from dataframe
    city_name=row['City']
    
    # add new key to params for query search by city name
    params['q']=city_name
    
    # assemble url and make api request
    response=requests.get(base_url,params=params).json()
    
    try:
        print(f'Processing Record {count}: {city_name}')
    
        df.loc[index, 'Cloudiness']=response['clouds']['all']
        df.loc[index, 'Country']=response['sys']['country']
        df.loc[index, 'Date']=response['dt']
        df.loc[index,'Humidity']=response['main']['humidity']
        df.loc[index,'Lat']=response['coord']['lat']
        df.loc[index,'Lng']=response['coord']['lon']
        df.loc[index,'Max Temp']=response['main']['temp_max']
        df.loc[index,'Wind Speed']=response['wind']['speed']
    except(KeyError):
        print("Missing field/result...skipping")
    
    count=count+1
# Out:
# Processing Record 1: kruisfontein
# Processing Record 2: waipawa
# Processing Record 3: mouzakion
# Missing field/result...skipping
# Processing Record 4: castro
# Processing Record 5: manoel urbano
# Processing Record 6: mataura
# Processing Record 7: saskylakh
# Processing Record 8: yershov
# Missing field/result...skipping
# Processing Record 9: ushuaia
# Processing Record 10: kapaa
# Processing Record 11: nelson bay
# Processing Record 12: georgetown
# Processing Record 13: victoria
# Processing Record 14: taolanaro
# Missing field/result...skipping
# Processing Record 15: illoqqortoormiut
# Missing field/result...skipping
# Processing Record 16: cartagena
# Processing Record 17: yenagoa
# Processing Record 18: wilmington
# Processing Record 19: saint-philippe
# Processing Record 20: puerto ayora
# Processing Record 21: samusu
# Missing field/result...skipping
# Processing Record 22: ardakan
# Processing Record 23: vanimo
# Processing Record 24: huesca
# Processing Record 25: hue
# Processing Record 26: khatanga
# Processing Record 27: ilulissat
# Processing Record 28: port macquarie
# Processing Record 29: castlegar
# Processing Record 30: carnarvon
# Processing Record 31: nemuro
# Processing Record 32: beloha
# Processing Record 33: morristown
# Processing Record 34: pacific grove
# Processing Record 35: vardo
# Processing Record 36: port elizabeth
# Processing Record 37: lavrentiya
# Processing Record 38: kaitangata
# Processing Record 39: vila franca do campo
# Processing Record 40: albany
# Processing Record 41: college
# Processing Record 42: kununurra
# Processing Record 43: eskasem
# Missing field/result...skipping
# Processing Record 44: coria
# Processing Record 45: yerbogachen
# Processing Record 46: bredasdorp
# Processing Record 47: sioux lookout
# Processing Record 48: perivolion
# Processing Record 49: punta arenas
# Processing Record 50: atherton
# Processing Record 51: san felipe
# Processing Record 52: atuona
# Processing Record 53: bairiki
# Missing field/result...skipping
# Processing Record 54: rikitea
# Processing Record 55: darnah
# Processing Record 56: jamestown
# Processing Record 57: tasiilaq
# Processing Record 58: vila velha
# Processing Record 59: torbay
# Processing Record 60: talnakh
# Processing Record 61: butaritari
# Processing Record 62: duz
# Missing field/result...skipping
# Processing Record 63: gazanjyk
# Processing Record 64: dingle
# Processing Record 65: ponta do sol
# Processing Record 66: clyde river
# Processing Record 67: lalibela
# Processing Record 68: east london
# Processing Record 69: shache
# Processing Record 70: te anau
# Processing Record 71: chapadinha
# Processing Record 72: bengkulu
# Missing field/result...skipping
# Processing Record 73: nikolskoye
# Processing Record 74: luderitz
# Processing Record 75: banda aceh
# Processing Record 76: wulanhaote
# Missing field/result...skipping
# Processing Record 77: vaini
# Processing Record 78: quatre cocos
# Processing Record 79: sitka
# Processing Record 80: kodiak
# Processing Record 81: bluff
# Processing Record 82: qaanaaq
# Processing Record 83: marcona
# Missing field/result...skipping
# Processing Record 84: hithadhoo
# Processing Record 85: namibe
# Processing Record 86: leningradskiy
# Processing Record 87: mys shmidta
# Missing field/result...skipping
# Processing Record 88: saint george
# Processing Record 89: bethel
# Processing Record 90: busselton
# Processing Record 91: ternovka
# Processing Record 92: eau claire
# Processing Record 93: tuktoyaktuk
# Processing Record 94: farkhor
# Processing Record 95: new norfolk
# Processing Record 96: norman wells
# Processing Record 97: dikson
# Processing Record 98: muragachha
# Missing field/result...skipping
# Processing Record 99: taburi
# Missing field/result...skipping
# Processing Record 100: egvekinot
# Processing Record 101: arraial do cabo
# Processing Record 102: padang
# Processing Record 103: tuatapere
# Processing Record 104: severo-kurilsk
# Processing Record 105: lagoa formosa
# Processing Record 106: petropavlovsk-kamchatskiy
# Processing Record 107: sao filipe
# Processing Record 108: crab hill
# Missing field/result...skipping
# Processing Record 109: coquimbo
# Processing Record 110: porto novo
# Processing Record 111: palabuhanratu
# Missing field/result...skipping
# Processing Record 112: ekhabi
# Processing Record 113: lasa
# Processing Record 114: barentsburg
# Missing field/result...skipping
# Processing Record 115: constitucion
# Processing Record 116: port alfred
# Processing Record 117: grand river south east
# Missing field/result...skipping
# Processing Record 118: verkhoyansk
# Processing Record 119: tsihombe
# Missing field/result...skipping
# Processing Record 120: cottonwood
# Processing Record 121: kudahuvadhoo
# Processing Record 122: telfs
# Processing Record 123: pocone
# Processing Record 124: port lincoln
# Processing Record 125: vagur
# Processing Record 126: lebu
# Processing Record 127: aksarka
# Processing Record 128: san quintin
# Processing Record 129: hokitika
# Processing Record 130: alice springs
# Processing Record 131: puerto del rosario
# Processing Record 132: cape town
# Processing Record 133: aloleng
# Processing Record 134: sivas
# Processing Record 135: esna
# Processing Record 136: port hedland
# Processing Record 137: sahbuz
# Processing Record 138: rawah
# Missing field/result...skipping
# Processing Record 139: tarakan
# Processing Record 140: ribeira grande
# Processing Record 141: diego de almagro
# Processing Record 142: saint-jean-port-joli
# Missing field/result...skipping
# Processing Record 143: tommot
# Processing Record 144: forestville
# Processing Record 145: zhangye
# Processing Record 146: hualmay
# Processing Record 147: upernavik
# Processing Record 148: port-gentil
# Processing Record 149: bambous virieux
# Processing Record 150: chuy
# Processing Record 151: nouadhibou
# Processing Record 152: ondo
# Processing Record 153: kuryk
# Processing Record 154: port-cartier
# Processing Record 155: samarai
# Processing Record 156: letlhakane
# Processing Record 157: mubi
# Processing Record 158: balkhash
# Processing Record 159: lorengau
# Processing Record 160: mercedes
# Processing Record 161: lata
# Processing Record 162: sisimiut
# Processing Record 163: chokurdakh
# Processing Record 164: bassano
# Processing Record 165: homer
# Processing Record 166: grand centre
# Missing field/result...skipping
# Processing Record 167: hearst
# Processing Record 168: batagay
# Processing Record 169: perth
# Processing Record 170: makung
# Missing field/result...skipping
# Processing Record 171: nakodar
# Processing Record 172: portland
# Processing Record 173: artyk
# Missing field/result...skipping
# Processing Record 174: hermanus
# Processing Record 175: surt
# Processing Record 176: verkhniy baskunchak
# Processing Record 177: belushya guba
# Missing field/result...skipping
# Processing Record 178: temaraia
# Missing field/result...skipping
# Processing Record 179: pangnirtung
# Processing Record 180: nizhneyansk
# Missing field/result...skipping
# Processing Record 181: borbon
# Processing Record 182: atar
# Processing Record 183: attawapiskat
# Missing field/result...skipping
# Processing Record 184: fort nelson
# Processing Record 185: omsukchan
# Processing Record 186: chicama
# Processing Record 187: dalvik
# Processing Record 188: acarau
# Missing field/result...skipping
# Processing Record 189: djambala
# Processing Record 190: eldikan
# Missing field/result...skipping
# Processing Record 191: hilo
# Processing Record 192: marysville
# Processing Record 193: yara
# Processing Record 194: yellowknife
# Processing Record 195: biltine
# Processing Record 196: barrow
# Processing Record 197: magadan
# Processing Record 198: muroto
# Processing Record 199: hobart
# Processing Record 200: zamora
# Processing Record 201: moose factory
# Processing Record 202: husavik
# Processing Record 203: nizwa
# Processing Record 204: srednekolymsk
# Processing Record 205: tamworth
# Processing Record 206: pithoragarh
# Processing Record 207: bam
# Processing Record 208: daru
# Processing Record 209: aquiraz
# Processing Record 210: santiago de chuco
# Processing Record 211: mecca
# Processing Record 212: zheleznodorozhnyy
# Processing Record 213: avarua
# Processing Record 214: silago
# Processing Record 215: okato
# Processing Record 216: kalmunai
# Processing Record 217: mayo
# Processing Record 218: thompson
# Processing Record 219: anadyr
# Processing Record 220: saint-joseph
# Processing Record 221: sentyabrskiy
# Missing field/result...skipping
# Processing Record 222: ahipara
# Processing Record 223: coahuayana
# Processing Record 224: rawson
# Processing Record 225: maridi
# Missing field/result...skipping
# Processing Record 226: cilegon
# Processing Record 227: komsomolskiy
# Processing Record 228: comodoro rivadavia
# Processing Record 229: yusva
# Missing field/result...skipping
# Processing Record 230: kamina
# Processing Record 231: viedma
# Processing Record 232: saldanha
# Processing Record 233: griffith
# Processing Record 234: los llanos de aridane
# Processing Record 235: nome
# Processing Record 236: saint-augustin
# Processing Record 237: carballo
# Processing Record 238: touros
# Processing Record 239: faanui
# Processing Record 240: adrar
# Processing Record 241: yulara
# Processing Record 242: richards bay
# Processing Record 243: conceicao do araguaia
# Processing Record 244: kathu
# Processing Record 245: merauke
# Processing Record 246: taoudenni
# Processing Record 247: matagami
# Processing Record 248: san jose
# Processing Record 249: little current
# Processing Record 250: mar del plata
# Processing Record 251: marisel
# Processing Record 252: kutulik
# Processing Record 253: kazalinsk
# Missing field/result...skipping
# Processing Record 254: lincoln
# Processing Record 255: presidencia roque saenz pena
# Processing Record 256: agalatovo
# Processing Record 257: port blair
# Processing Record 258: baykit
# Processing Record 259: salinas
# Processing Record 260: siderno
# Processing Record 261: mahebourg
# Processing Record 262: rocky mountain house
# Processing Record 263: hasaki
# Processing Record 264: cabo san lucas
# Processing Record 265: cidreira
# Processing Record 266: tiksi
# Processing Record 267: sinkat
# Missing field/result...skipping
# Processing Record 268: kailua
# Processing Record 269: carutapera
# Processing Record 270: mount pleasant
# Processing Record 271: luau
# Processing Record 272: cayenne
# Processing Record 273: katangli
# Processing Record 274: mwinilunga
# Processing Record 275: tumen
# Processing Record 276: margate
# Processing Record 277: lagoa
# Processing Record 278: segezha
# Processing Record 279: fushan
# Processing Record 280: poum
# Processing Record 281: road town
# Processing Record 282: lobva
# Processing Record 283: angren
# Processing Record 284: evanston
# Processing Record 285: anzio
# Processing Record 286: oktyabrskiy
# Processing Record 287: santiago de cao
# Processing Record 288: viligili
# Missing field/result...skipping
# Processing Record 289: inuvik
# Processing Record 290: ust-kamchatsk
# Missing field/result...skipping
# Processing Record 291: pevek
# Processing Record 292: eten
# Processing Record 293: phan thiet
# Processing Record 294: ypsonas
# Processing Record 295: himora
# Missing field/result...skipping
# Processing Record 296: el faiyum
# Missing field/result...skipping
# Processing Record 297: traverse city
# Processing Record 298: kautokeino
# Processing Record 299: charlestown
# Processing Record 300: tsiroanomandidy
# Processing Record 301: amderma
# Missing field/result...skipping
# Processing Record 302: sur
# Processing Record 303: najran
# Processing Record 304: ratnagiri
# Processing Record 305: airai
# Processing Record 306: kahului
# Processing Record 307: umarizal
# Processing Record 308: sakakah
# Missing field/result...skipping
# Processing Record 309: katsuura
# Processing Record 310: kindu
# Processing Record 311: pimentel
# Processing Record 312: weihai
# Processing Record 313: bilibino
# Processing Record 314: ocampo
# Processing Record 315: burnie
# Processing Record 316: king city
# Processing Record 317: dalmatovo
# Processing Record 318: broken hill
# Processing Record 319: lovington
# Processing Record 320: santa barbara
# Processing Record 321: provideniya
# Processing Record 322: itoman
# Processing Record 323: san cristobal
# Processing Record 324: bandarbeyla
# Processing Record 325: bushehr
# Processing Record 326: marataizes
# Processing Record 327: geraldton
# Processing Record 328: port hardy
# Processing Record 329: conceicao da barra
# Processing Record 330: champerico
# Processing Record 331: baruun-urt
# Processing Record 332: vaitape
# Processing Record 333: riyadh
# Processing Record 334: along
# Processing Record 335: anloga
# Processing Record 336: sosnovo-ozerskoye
# Processing Record 337: guerrero negro
# Processing Record 338: havoysund
# Processing Record 339: mount isa
# Processing Record 340: libertad
# Processing Record 341: saurimo
# Processing Record 342: marawi
# Processing Record 343: hami
# Processing Record 344: paamiut
# Processing Record 345: the valley
# Processing Record 346: sidi ali
# Processing Record 347: warqla
# Missing field/result...skipping
# Processing Record 348: aripuana
# Processing Record 349: rudbar
# Missing field/result...skipping
# Processing Record 350: kawalu
# Processing Record 351: wamba
# Processing Record 352: kouango
# Processing Record 353: auki
# Processing Record 354: hutang
# Processing Record 355: mehtar lam
# Processing Record 356: killybegs
# Processing Record 357: vung tau
# Processing Record 358: eyl
# Processing Record 359: wanning
# Processing Record 360: salym
# Processing Record 361: shitanjing
# Processing Record 362: longyearbyen
# Processing Record 363: altamira
# Processing Record 364: whitehorse
# Processing Record 365: bethanien
# Processing Record 366: samalaeulu
# Missing field/result...skipping
# Processing Record 367: kurilsk
# Processing Record 368: porto walter
# Processing Record 369: sulangan
# Processing Record 370: gavrilovka vtoraya
# Processing Record 371: santa cruz
# Processing Record 372: aklavik
# Processing Record 373: calvinia
# Processing Record 374: kavaratti
# Processing Record 375: tual
# Processing Record 376: dakoro
# Processing Record 377: chapais
# Processing Record 378: khandyga
# Processing Record 379: nogliki
# Processing Record 380: beringovskiy
# Processing Record 381: oussouye
# Processing Record 382: morki
# Processing Record 383: saleaula
# Missing field/result...skipping
# Processing Record 384: narsaq
# Processing Record 385: lodwar
# Processing Record 386: itarema
# Processing Record 387: harper
# Processing Record 388: hostotipaquillo
# Processing Record 389: adre
# Processing Record 390: narasannapeta
# Processing Record 391: udachnyy
# Processing Record 392: kapit
# Processing Record 393: flinders
# Processing Record 394: jiujiang
# Processing Record 395: honiara
# Processing Record 396: sebinkarahisar
# Processing Record 397: tumannyy
# Missing field/result...skipping
# Processing Record 398: dongsheng
# Processing Record 399: labutta
# Missing field/result...skipping
# Processing Record 400: biryusinsk
# Processing Record 401: hervey bay
# Processing Record 402: sorong
# Processing Record 403: panama city
# Processing Record 404: caravelas
# Processing Record 405: varnamo
# Processing Record 406: teya
# Processing Record 407: brae
# Processing Record 408: huangmei
# Processing Record 409: kabanjahe
# Processing Record 410: codrington
# Processing Record 411: samarkand
# Processing Record 412: bababe
# Missing field/result...skipping
# Processing Record 413: salinopolis
# Processing Record 414: itatskiy
# Processing Record 415: ilinskiy
# Processing Record 416: las cruces
# Processing Record 417: mehriz
# Processing Record 418: mstera
# Processing Record 419: mtwara
# Processing Record 420: saint anthony
# Processing Record 421: encruzilhada do sul
# Processing Record 422: haibowan
# Missing field/result...skipping
# Processing Record 423: raudeberg
# Processing Record 424: ouro preto do oeste
# Processing Record 425: prince rupert
# Processing Record 426: slave lake
# Processing Record 427: faro
# Processing Record 428: muromtsevo
# Processing Record 429: panaba
# Processing Record 430: umm lajj
# Processing Record 431: cockburn town
# Processing Record 432: oranjemund
# Processing Record 433: deputatskiy
# Processing Record 434: monterey
# Processing Record 435: oistins
# Processing Record 436: birnin kebbi
# Processing Record 437: inongo
# Processing Record 438: rudsar
# Processing Record 439: grindavik
# Processing Record 440: vannes
# Processing Record 441: gat
# Processing Record 442: tura
# Processing Record 443: waingapu
# Processing Record 444: zhuanghe
# Processing Record 445: koshurnikovo
# Processing Record 446: eagle pass
# Processing Record 447: nanortalik
# Processing Record 448: cherskiy
# Processing Record 449: belaya gora
# Processing Record 450: meulaboh
# Processing Record 451: calama
# Processing Record 452: inhambane
# Processing Record 453: kaeo
# Processing Record 454: wageningen
# Processing Record 455: les cayes
# Processing Record 456: valparaiso
# Processing Record 457: sambava
# Processing Record 458: gay
# Processing Record 459: isangel
# Processing Record 460: tierranueva
# Processing Record 461: ostrovnoy
# Processing Record 462: port augusta
# Processing Record 463: hamilton
# Processing Record 464: ginir
# Processing Record 465: bathsheba
# Processing Record 466: dubbo
# Processing Record 467: nishihara
# Processing Record 468: huarmey
# Processing Record 469: mehamn
# Processing Record 470: maracaibo
# Processing Record 471: ulaanbaatar
# Processing Record 472: shelburne
# Processing Record 473: tome
# Processing Record 474: papara
# Processing Record 475: westport
# Processing Record 476: moyo
# Missing field/result...skipping
# Processing Record 477: matamoros
# Processing Record 478: dolbeau
# Missing field/result...skipping
# Processing Record 479: nenjiang
# Processing Record 480: sorgun
# Processing Record 481: mazatlan
# Processing Record 482: khorixas
# Processing Record 483: urdoma
# Processing Record 484: montpellier
# Processing Record 485: bubaque
# Processing Record 486: poronaysk
# Processing Record 487: vaitupu
# Missing field/result...skipping
# Processing Record 488: la ronge
# Processing Record 489: placido de castro
# Processing Record 490: viesca
# Processing Record 491: farmington
# Processing Record 492: nantucket
# Processing Record 493: vostok
# Processing Record 494: kloulklubed
# Processing Record 495: salalah
# Processing Record 496: inverell
# Processing Record 497: axim
# Processing Record 498: amberley
# Processing Record 499: gobabis
# Processing Record 500: sim
# Processing Record 501: kavieng
# Processing Record 502: urumqi
# Missing field/result...skipping
# Processing Record 503: qandala
# Processing Record 504: coihaique
# Processing Record 505: sapouy
# Processing Record 506: solnechnyy
# Processing Record 507: okhotsk
# Processing Record 508: porbandar
# Processing Record 509: gonzales
# Processing Record 510: qasigiannguit
# Processing Record 511: tiznit
# Processing Record 512: qibili
# Missing field/result...skipping
# Processing Record 513: odda
# Processing Record 514: san patricio
# Processing Record 515: ushtobe
# Processing Record 516: sochi
# Processing Record 517: kadykchan
# Missing field/result...skipping
# Processing Record 518: ferzikovo
# Processing Record 519: ouango
# Processing Record 520: noumea
# Processing Record 521: kyela
# Processing Record 522: rio grande
# Processing Record 523: zyryanka
# Processing Record 524: odweyne
# Missing field/result...skipping
# Processing Record 525: tshikapa
# Processing Record 526: nisia floresta
# Processing Record 527: chernyshevskiy
# Processing Record 528: puerto baquerizo moreno
# Processing Record 529: tautira
# Processing Record 530: boffa
# Processing Record 531: cairns
# Processing Record 532: vestmannaeyjar
# Processing Record 533: mapiripan
# Processing Record 534: shumskiy
# Processing Record 535: tarancon
# Processing Record 536: at-bashi
# Processing Record 537: rio gallegos
# Processing Record 538: santa maria
# Processing Record 539: umzimvubu
# Missing field/result...skipping
# Processing Record 540: sakyla
# Processing Record 541: pochutla
# Processing Record 542: bonfim
# Processing Record 543: sorkjosen
# Missing field/result...skipping
# Processing Record 544: acapulco
# Processing Record 545: tortoli
# Processing Record 546: finnsnes
# Processing Record 547: saravan
# Processing Record 548: ancud
# Processing Record 549: luoyang
# Processing Record 550: yeppoon
# Processing Record 551: kalvarija
# Processing Record 552: dicabisagan
# Processing Record 553: windsor
# Processing Record 554: esperance
# Processing Record 555: morwell
# Processing Record 556: ouesso
# Processing Record 557: le moule
# Processing Record 558: plettenberg bay
# Processing Record 559: denpasar
# Processing Record 560: toora-khem
# Processing Record 561: klaksvik
# Processing Record 562: souillac
# Processing Record 563: vao
# Processing Record 564: ketchikan
# Processing Record 565: gogrial
# Missing field/result...skipping
# Processing Record 566: san fernando
# Processing Record 567: alaverdi
# Processing Record 568: evensk
# Processing Record 569: kirakira
# Processing Record 570: barbar
# Missing field/result...skipping
# Processing Record 571: gunnedah
# Processing Record 572: mokhsogollokh
# Processing Record 573: miranda
# Processing Record 574: reconquista
# Processing Record 575: qaqortoq
# Processing Record 576: yakeshi
# Processing Record 577: kidal
# Processing Record 578: krasnokamensk
# Processing Record 579: ulundi
# Processing Record 580: male
# Processing Record 581: otradnoye
# Processing Record 582: buckeye
# Processing Record 583: namatanai
# Processing Record 584: krasnoselkup
# Missing field/result...skipping
# Processing Record 585: qui nhon
# Missing field/result...skipping
# Processing Record 586: mayumba
# Processing Record 587: nagato
# Processing Record 588: zhigansk
# Processing Record 589: serra talhada
# Processing Record 590: ushumun
# Processing Record 591: dryden
# Processing Record 592: masoko
# Processing Record 593: alofi
# Processing Record 594: taicheng
# Processing Record 595: moron
# Processing Record 596: layou
# Missing field/result...skipping
# Processing Record 597: mastic beach
# Processing Record 598: haines junction
# Processing Record 599: kolosovka
# Processing Record 600: ozgon
# Missing field/result...skipping
# Processing Record 601: kamenka
# Processing Record 602: gladstone
# Processing Record 603: kyra
# Missing field/result...skipping
# Processing Record 604: tilichiki
# Processing Record 605: la serena
# Processing Record 606: pisco
# Processing Record 607: mabaruma
# Processing Record 608: ulladulla

# %% [markdown]
# ## Convert Raw Data into Dataframe
#     Export the city data into a .csv.
#     Display the DataFrame

# %%
df.to_csv(output_data_file,header=True)

# %%
print(df.count())
df.head()
# Out:
# City          608
# Cloudiness    608
# Country       608
# Date          608
# Humidity      608
# Lat           608
# Lng           608
# Max Temp      608
# Wind Speed    608
# dtype: int64
#             City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0   kruisfontein          0      ZA  1573845491       95    -34   24.73
# 1        waipawa         76      NZ  1573845766       71 -39.94  176.59
# 2      mouzakion
# 3         castro         40      CL  1573845466       55 -42.48  -73.76
# 4  manoel urbano         97      BR  1573845767       93  -8.84  -69.26
#
#   Max Temp Wind Speed
# 0    62.46       3.89
# 1       61      15.99
# 2
# 3     60.8      10.29
# 4    78.46       3.13

# %%
## investigate the data collected.
## see how many cities are missing the field results we are interested in plotting and identify those cities

missing_data_cities=[]
for index, row in df.iterrows():
    if row['Max Temp'] == '' or row['Humidity']== '' or row['Cloudiness']=='' or row['Wind Speed']== '':
        missing_data_cities.append(row['City'])
#         print(index, row)

print(len(missing_data_cities))
print(missing_data_cities)
# Out:
# 65
# ['mouzakion', 'yershov', 'taolanaro', 'illoqqortoormiut', 'samusu', 'eskasem', 'bairiki', 'duz', 'bengkulu', 'wulanhaote', 'marcona', 'mys shmidta', 'muragachha', 'taburi', 'crab hill', 'palabuhanratu', 'barentsburg', 'grand river south east', 'tsihombe', 'rawah', 'saint-jean-port-joli', 'grand centre', 'makung', 'artyk', 'belushya guba', 'temaraia', 'nizhneyansk', 'attawapiskat', 'acarau', 'eldikan', 'sentyabrskiy', 'maridi', 'yusva', 'kazalinsk', 'sinkat', 'viligili', 'ust-kamchatsk', 'himora', 'el faiyum', 'amderma', 'sakakah', 'warqla', 'rudbar', 'samalaeulu', 'saleaula', 'tumannyy', 'labutta', 'bababe', 'haibowan', 'moyo', 'dolbeau', 'vaitupu', 'urumqi', 'qibili', 'kadykchan', 'odweyne', 'umzimvubu', 'sorkjosen', 'gogrial', 'barbar', 'krasnoselkup', 'qui nhon', 'layou', 'ozgon', 'kyra']

# %%
## drop the rows in the dataframe that have missing data fields we are interested in plotting
## use the list of cities missing data to gather a list of their indexs and then drop those rows
row_drops=[]

for i in missing_data_cities:
    row_d=df[df['City']==i].index
    row_drops.append(row_d)
# print(row_drops)

new_df=df.drop(df.index[row_drops])
print(new_df.count())
new_df.head()
# Out:
# City          543
# Cloudiness    543
# Country       543
# Date          543
# Humidity      543
# Lat           543
# Lng           543
# Max Temp      543
# Wind Speed    543
# dtype: int64
#             City Cloudiness Country        Date Humidity    Lat     Lng  \
# 0   kruisfontein          0      ZA  1573845491       95    -34   24.73
# 1        waipawa         76      NZ  1573845766       71 -39.94  176.59
# 3         castro         40      CL  1573845466       55 -42.48  -73.76
# 4  manoel urbano         97      BR  1573845767       93  -8.84  -69.26
# 5        mataura         61      NZ  1573845472       93 -46.19  168.86
#
#   Max Temp Wind Speed
# 0    62.46       3.89
# 1       61      15.99
# 3     60.8      10.29
# 4    78.46       3.13
# 5    51.01       5.01

# %%
## storing date of data pull from dataframe in variable to use when plotting data
data_pull_date=time.localtime(new_df['Date'][0])
print(data_pull_date)
data_date=f'{data_pull_date[1]}/{data_pull_date[2]}/{data_pull_date[0]}'
print(data_date)
# Out:
# time.struct_time(tm_year=2019, tm_mon=11, tm_mday=15, tm_hour=13, tm_min=18, tm_sec=11, tm_wday=4, tm_yday=319, tm_isdst=0)
# 11/15/2019

# %% [markdown]
# ## Plotting the Data
#     Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
#     Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Max Temp

# %%
x_axis=new_df['Lat']
temp_data=new_df['Max Temp']

plt.scatter(x=x_axis, y=temp_data, marker='o', facecolor='blue', edgecolors='black')
plt.xlim(min(new_df['Lat'])-5,max(new_df['Lat'])+5)
plt.ylim(min(new_df['Max Temp'])-5,max(new_df['Max Temp'])+5)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Fahrenheit)")
plt.title(f"City Latitude vs. Max Temperature {data_date}")
plt.grid()
plt.savefig('output_data/LatVsTemp.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity

# %%
hum_data=new_df['Humidity']

plt.scatter(x=x_axis, y=hum_data, marker='o', facecolor='blue', edgecolors='black')
plt.xlim(min(new_df['Lat'])-5,max(new_df['Lat'])+5)
plt.ylim(min(new_df['Humidity'])-5,max(new_df['Humidity'])+5)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity {data_date}")
plt.grid()
plt.savefig('output_data/LatVsHum.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness

# %%
cld_data=new_df['Cloudiness']

plt.scatter(x=x_axis, y=cld_data, marker='o', facecolor='blue', edgecolors='black')
plt.xlim(min(new_df['Lat'])-5,max(new_df['Lat'])+5)
plt.ylim(min(new_df['Cloudiness'])-5,max(new_df['Cloudiness'])+5)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs. Cloudiness {data_date}")
plt.grid()
plt.savefig('output_data/LatVsClouds.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed

# %%
wsp_data=new_df['Wind Speed']

plt.scatter(x=x_axis, y=wsp_data, marker='o', facecolor='blue', edgecolors='black')
plt.xlim(min(new_df['Lat'])-2,max(new_df['Lat'])+2)
plt.ylim(min(new_df['Wind Speed'])-2,max(new_df['Wind Speed'])+2)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs. Wind Speed {data_date}")
plt.grid()
plt.savefig('output_data/LatVsWind.png')
plt.show()

# %%
east=0
west=0
for i in new_df['Lat']:
    if i>0:
        east=east+1
    else:
        west=west+1

print(east)
print(west)
# Out:
# 368
# 175

# %% [markdown]
# ## My Observations:
#
# Based on the City Latitude vs. Max Temperature plot results, it appears that cities with latitudes West of the equator (latitude is 0 to -90) have higher max temperatures than cities with latitudes east of the equator (latitude is 0 to 90).
